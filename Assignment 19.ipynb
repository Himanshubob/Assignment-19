# %% [markdown]
# # Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# # ans .. we have to use the exception class while creating a custom excetion because it is the class for all the excpetion in python by extending the exception class , we can inherit its properties and method ,and also customize them according to our needs

# %% [markdown]
# #  Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_subclasses(exception , indent=0):
    print(" "* indent +exception.__name__)
    for subclass in exception.__subclasses__():
        print_subclasses(subclass,indent+4)
print_subclasses(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             herror
#             gaierror
#             SSLError
#                 SSLCertVerificationError
# ...

# %% [markdown]
# # Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# # ans..The arithmeticerror class is the base class for those built -in exceptions that are reised for various arithmetic error ,such as when attempting to divideby zero

# %%
a=12

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
float('him')+1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 float('him')+1
#
# ValueError: could not convert string to float: 'him'

# %% [markdown]
# # Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# # An importerror is an exception that is raised when an import statement fails to load a module or a name from a module .
# # the module or name does not exist or is misspelled
# # the module or name is not compatible with the current version of python

# %% [markdown]
# # Q6. List down some best practices for exception handling in python.

# %% [markdown]
# # 1.exception
# # 2. spectific exception
# # 3.descriptive messages and custom attributes when creating your own exception
